# %%
import pandas as pd

# %%
hurun_独角兽 = pd.read_html('https://www.hurun.net/zh-CN/Info/Detail?num=L9SQPH9FKJB1')[-3]
hurun_独角兽[0:1].values.tolist()[0]
df_hurun = hurun_独角兽[1:]
df_hurun.columns = hurun_独角兽[0:1].values.tolist()[0]
df_hurun['价值（亿元人民币）'] = df_hurun['价值（亿元人民币）'].astype('int64')
df_hurun
# Out:
# C:\Users\17728\AppData\Local\Temp\ipykernel_15320\3601636554.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hurun['价值（亿元人民币）'] = df_hurun['价值（亿元人民币）'].astype('int64')
#      排名 排名变化                 企业名称  价值（亿元人民币） 价值变化（亿元人民币）  国家     城市    行业
# 1     1    0                   抖音      13400      -10050  中国     北京  社交媒体
# 2     2    1               SpaceX       8400        1680  美国    洛杉矶    航天
# 3     3   -1                 蚂蚁集团       8000       -2010  中国     杭州  金融科技
# 4     4    0               Stripe       4100       -2210  美国    旧金山  金融科技
# 5     5   11                Shein       4000        2680  中国     广州  电子商务
# ..   ..  ...                  ...        ...         ...  ..    ...   ...
# 97   95  -16        Impossible 食品        470           0  美国  雷德伍德城  食品饮料
# 98   95  -16                   微医        470           0  中国     杭州  健康科技
# 99   99   58                 蜂巢能源        460         190  中国     常州   新能源
# 100  99   -6           Better.com        460          60  美国     纽约  金融科技
# 101  99  -20  Automation Anywhere        460         -10  美国    圣何塞  人工智能
#
# [101 rows x 8 columns]

# %%
df_hurun_pivot = df_hurun.pivot_table(index="国家",columns="行业",values="价值变化（亿元人民币）",aggfunc="max")
df_hurun_pivot
# Out:
# 行业    人工智能 企业服务   保险 健康科技  共享经济   分析   区块链  大数据   快递 教育科技  ...   游戏   物流 生物科技  \
# 国家                                                         ...
# 中国     200  180    0  700   New  NaN   NaN    0  NaN  NaN  ...  NaN  200  NaN
# 以色列    NaN  NaN  NaN  NaN   NaN  NaN   400  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 印度     NaN  NaN  NaN  NaN  -160  NaN   NaN  NaN  340   70  ...  200  NaN  NaN
# 印度尼西亚  NaN  NaN  NaN  NaN     0  NaN   NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 土耳其    NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  300  NaN  ...  NaN  NaN  NaN
# 墨西哥    NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 巴哈马    NaN  NaN  NaN  NaN   NaN  NaN  -340  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 德国     NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 澳大利亚   NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 瑞典     NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 瑞士     NaN  NaN  NaN  NaN   NaN  NaN   -70  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 美国       0  New  NaN  750   640  310    70    0    0  NaN  ...    0  320   10
# 英国     NaN  NaN  NaN  NaN   NaN  NaN   370  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 越南     NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 韩国     NaN  NaN  NaN  NaN   NaN  NaN   New  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 马耳他    NaN  NaN  NaN  NaN   NaN  NaN  2010  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
# 行业    电子商务    社交媒体 网络安全    航天  软件服务 金融科技 食品饮料
# 国家
# 中国     510  -10050  NaN   NaN     0  200    0
# 以色列    NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 印度     NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 印度尼西亚    0     NaN  NaN   NaN   NaN  NaN  NaN
# 土耳其    NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 墨西哥     10     NaN  NaN   NaN   NaN  NaN  NaN
# 巴哈马    NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 德国     NaN     NaN  NaN   NaN  -190  NaN  NaN
# 澳大利亚   NaN     NaN  NaN   NaN  -940  NaN  NaN
# 瑞典     NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 瑞士     NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 美国     400       0    0  1680   650  New    0
# 英国     NaN     NaN  NaN   NaN   230  870  NaN
# 越南     NaN     NaN  NaN   NaN   NaN  NaN  NaN
# 韩国     500     NaN  NaN   NaN   NaN  NaN  NaN
# 马耳他    NaN     NaN  NaN   NaN   NaN  NaN  NaN
#
# [16 rows x 26 columns]

# %%
行业 = df_hurun_pivot.columns
行业
# Out:
# Index(['人工智能', '企业服务', '保险', '健康科技', '共享经济', '分析', '区块链', '大数据', '快递', '教育科技',
#        '数字科技', '新能源', '新能源汽车', '新零售', '机器人', '消费品', '游戏', '物流', '生物科技', '电子商务',
#        '社交媒体', '网络安全', '航天', '软件服务', '金融科技', '食品饮料'],
#       dtype='object', name='行业')

# %%
中国 = df_hurun_pivot.index

# %%
# !pip install pyechart
# Out:
# ERROR: Could not find a version that satisfies the requirement pyechart (from versions: none)
# ERROR: No matching distribution found for pyechart
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values(), stack="stack1")
    .add_yaxis("商家B", Faker.values(), stack="stack1")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（全部）"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ad3cf5cfa115445bb7461f0743cd4bc4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ad3cf5cfa115445bb7461f0743cd4bc4 = echarts.init(
#                     document.getElementById('ad3cf5cfa115445bb7461f0743cd4bc4'), 'white', {renderer: 'canvas'});
#                 var option_ad3cf5cfa115445bb7461f0743cd4bc4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 27,
#                 60,
#                 44,
#                 56,
#                 146,
#                 139,
#                 43
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 20,
#                 93,
#                 43,
#                 74,
#                 91,
#                 127,
#                 48
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "Bar-\u5806\u53e0\u6570\u636e\uff08\u5168\u90e8\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_ad3cf5cfa115445bb7461f0743cd4bc4.setOption(option_ad3cf5cfa115445bb7461f0743cd4bc4);
#         });
#     </script>
